# %%
import pandas as pd
import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, ElectraForSequenceClassification, AdamW
from sklearn.model_selection import train_test_split
from transformers import ElectraModel, ElectraTokenizer
from tqdm.notebook import tqdm
import torch.nn as nn
import torch.nn.init as init
from sklearn.metrics import f1_score
data = pd.read_csv('/content/dialogues_data.csv')
data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#       감정                                                 문장
# 0  anger  일은 왜 해도 해도 끝이 없을까? 화가 난다.그냥 내가 해결하는 게 나아. 남들한테...
# 1  anger  이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나....
# 2  anger  회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...
# 3  anger  직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...
# 4  anger  얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나.상사인 나에게 먼...

# %%
data['문장'].nunique(), data['감정'].nunique()
# Out:
# (101011, 4)

# %%
data.drop_duplicates(subset=['문장'], inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data.loc[(data['감정'] == "anger"), '감정'] = 0
data.loc[(data['감정'] == "happy"), '감정'] = 1
data.loc[(data['감정'] == "panic"), '감정'] = 2
data.loc[(data['감정'] == "sadness"), '감정'] = 3

# %%
data
# Out:
#        감정                                                 문장
# 0       0  일은 왜 해도 해도 끝이 없을까? 화가 난다.그냥 내가 해결하는 게 나아. 남들한테...
# 1       0  이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나....
# 2       0  회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...
# 3       0  직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...
# 4       0  얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나.상사인 나에게 먼...
# ...    ..                                                ...
# 101006  2                                      오마이갓 믿을 수가 없어
# 101007  2                                     하느님 이거 너무 힘들어요
# 101008  2                                              엄청난 쇼
# 101009  2                                       오머나 정말 놀랐습니다
# 101010  2                               이게 무슨 일인지 이해가 안 돼요당황
#
# [101011 rows x 2 columns]

# %%
# GPU 사용
#device = torch.device("cuda")

# %%
class CsixDataset(Dataset):

  def __init__(self, data):
    self.dataset = data
    # 중복제거
    self.dataset.drop_duplicates(subset=['문장'], inplace=True)
    self.tokenizer =  AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")
    #"monologg/koelectra-small-v3-discriminator" small data
    #"monologg/koelectra-base-v3-discriminator" big data

    print(self.dataset.describe())

  def __len__(self):
    return len(self.dataset)

  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 0:2].values
    text = row[1]
    y = row[0]

    inputs = self.tokenizer(
        text,
        return_tensors='pt',
        truncation=True,
        max_length=75,
        pad_to_max_length=True,
        add_special_tokens=True
        )

    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask, y

# %%
# 데이터셋을 트레이닝과 테스트로 나눔
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# 트레이닝 데이터셋과 테스트 데이터셋 클래스 인스턴스 생성
train_dataset = CsixDataset(train_data)
test_dataset = CsixDataset(test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/263k [00:00<?, ?B/s]
#            감정                                                 문장
# count   80808                                              80808
# unique      4                                              80808
# top         1  할머니가 엄마를 들들 볶는 것을 볼 때마다 구역질이 나.할머니는 엄마에게 쌀밥도 못...
# freq    22660                                                  1
#            감정                   문장
# count   20203                20203
# unique      4                20203
# top         3  내 인생은 행복으로 가득 차 있어요
# freq     5591                    1

# %%
num_classes = 4  # 클래스 수에 맞게 설정
model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator", num_labels=num_classes)
# Out:
# pytorch_model.bin:   0%|          | 0.00/452M [00:00<?, ?B/s]
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
text, attention_mask, y = train_dataset[0]
model(text.unsqueeze(0), attention_mask=attention_mask.unsqueeze(0))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2674: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# SequenceClassifierOutput(loss=None, logits=tensor([[ 0.0523,  0.0228, -0.0807,  0.1499]], grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)

# %%
# 모델 레이어 보기
# model = model.to(device)

# %%
epochs = 4
batch_size = 16

# %%
optimizer = AdamW(model.parameters(), lr=5e-6)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:521: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

for epoch in range(epochs):
    # Training
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0

    for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
        optimizer.zero_grad()
        # y_batch = y_batch.to(device)
        y_pred = model(input_ids_batch, attention_mask=attention_masks_batch)[0]
        loss = F.cross_entropy(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        _, predicted = torch.max(y_pred, 1)
        correct_train += (predicted == y_batch).sum().item()
        total_train += len(y_batch)

        # Print batch accuracy
        batch_accuracy = correct_train / total_train
        print(f"Epoch {epoch+1}/{epochs}, Batch Accuracy: {batch_accuracy:.4f}")

    train_losses.append(train_loss / len(train_loader))
    train_accuracy = correct_train / total_train
    train_accuracies.append(train_accuracy)

    # Testing
    model.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0

    with torch.no_grad():
        for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
            # y_batch = y_batch.to(device)
            y_pred = model(input_ids_batch, attention_mask=attention_masks_batch)[0]
            loss = F.cross_entropy(y_pred, y_batch)

            test_loss += loss.item()

            _, predicted = torch.max(y_pred, 1)
            correct_test += (predicted == y_batch).sum().item()
            total_test += len(y_batch)

    test_losses.append(test_loss / len(test_loader))
    test_accuracy = correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_losses[-1]:.4f}, Test Accuracy: {test_accuracy:.4f}")

    # Calculate F1 score

    predicted_labels = []
    true_labels = []

    with torch.no_grad():
        for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
            # y_batch = y_batch.to(device)
            y_pred = model(input_ids_batch, attention_mask=attention_masks_batch)[0]
            _, predicted = torch.max(y_pred, 1)

            predicted_labels.extend(predicted.cpu().numpy())
            true_labels.extend(y_batch.cpu().numpy())

    f1 = f1_score(true_labels, predicted_labels, average='weighted')
    print("F1 Score:", f1)
# Out:
#   0%|          | 0/5051 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2674: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 1/4, Batch Accuracy: 0.2993
# Epoch 1/4, Batch Accuracy: 0.3019
# Epoch 1/4, Batch Accuracy: 0.3009
# Epoch 1/4, Batch Accuracy: 0.2977
# Epoch 1/4, Batch Accuracy: 0.2969
# Epoch 1/4, Batch Accuracy: 0.2971
# Epoch 1/4, Batch Accuracy: 0.2996
# Epoch 1/4, Batch Accuracy: 0.3030
# Epoch 1/4, Batch Accuracy: 0.3031
# Epoch 1/4, Batch Accuracy: 0.3043
# Epoch 1/4, Batch Accuracy: 0.3054
# Epoch 1/4, Batch Accuracy: 0.3065
# Epoch 1/4, Batch Accuracy: 0.3066
# Epoch 1/4, Batch Accuracy: 0.3077
# Epoch 1/4, Batch Accuracy: 0.3087
# Epoch 1/4, Batch Accuracy: 0.3134
# Epoch 1/4, Batch Accuracy: 0.3153
# Epoch 1/4, Batch Accuracy: 0.3188
# Epoch 1/4, Batch Accuracy: 0.3196
# Epoch 1/4, Batch Accuracy: 0.3213
# Epoch 1/4, Batch Accuracy: 0.3212
# Epoch 1/4, Batch Accuracy: 0.3219
# Epoch 1/4, Batch Accuracy: 0.3193
# Epoch 1/4, Batch Accuracy: 0.3200
# Epoch 1/4, Batch Accuracy: 0.3232
# Epoch 1/4, Batch Accuracy: 0.3263
# Epoch 1/4, Batch Accuracy: 0.3285
# Epoch 1/4, Batch Accuracy: 0.3315
# Epoch 1/4, Batch Accuracy: 0.3359
# Epoch 1/4, Batch Accuracy: 0.3403
# Epoch 1/4, Batch Accuracy: 0.3430
# Epoch 1/4, Batch Accuracy: 0.3464
# Epoch 1/4, Batch Accuracy: 0.3467
# Epoch 1/4, Batch Accuracy: 0.3493
# Epoch 1/4, Batch Accuracy: 0.3496
# Epoch 1/4, Batch Accuracy: 0.3499
# Epoch 1/4, Batch Accuracy: 0.3509
# Epoch 1/4, Batch Accuracy: 0.3518
# Epoch 1/4, Batch Accuracy: 0.3542
# Epoch 1/4, Batch Accuracy: 0.3558
# Epoch 1/4, Batch Accuracy: 0.3546
# Epoch 1/4, Batch Accuracy: 0.3548
# Epoch 1/4, Batch Accuracy: 0.3544
# Epoch 1/4, Batch Accuracy: 0.3572
# Epoch 1/4, Batch Accuracy: 0.3581
# Epoch 1/4, Batch Accuracy: 0.3595
# Epoch 1/4, Batch Accuracy: 0.3622
# Epoch 1/4, Batch Accuracy: 0.3605
# Epoch 1/4, Batch Accuracy: 0.3588
# Epoch 1/4, Batch Accuracy: 0.3589
# Epoch 1/4, Batch Accuracy: 0.3591
# Epoch 1/4, Batch Accuracy: 0.3617
# Epoch 1/4, Batch Accuracy: 0.3618
# Epoch 1/4, Batch Accuracy: 0.3613
# Epoch 1/4, Batch Accuracy: 0.3614
# Epoch 1/4, Batch Accuracy: 0.3627
# Epoch 1/4, Batch Accuracy: 0.3640
# Epoch 1/4, Batch Accuracy: 0.3653
# Epoch 1/4, Batch Accuracy: 0.3659
# Epoch 1/4, Batch Accuracy: 0.3654
# Epoch 1/4, Batch Accuracy: 0.3672
# Epoch 1/4, Batch Accuracy: 0.3678
# Epoch 1/4, Batch Accuracy: 0.3695
# Epoch 1/4, Batch Accuracy: 0.3701
# Epoch 1/4, Batch Accuracy: 0.3712
# Epoch 1/4, Batch Accuracy: 0.3729
# Epoch 1/4, Batch Accuracy: 0.3718
# Epoch 1/4, Batch Accuracy: 0.3724
# Epoch 1/4, Batch Accuracy: 0.3745
# Epoch 1/4, Batch Accuracy: 0.3755
# Epoch 1/4, Batch Accuracy: 0.3760
# Epoch 1/4, Batch Accuracy: 0.3760
# Epoch 1/4, Batch Accuracy: 0.3755
# Epoch 1/4, Batch Accuracy: 0.3750
# Epoch 1/4, Batch Accuracy: 0.3750
# Epoch 1/4, Batch Accuracy: 0.3755
# Epoch 1/4, Batch Accuracy: 0.3745
# Epoch 1/4, Batch Accuracy: 0.3755
# Epoch 1/4, Batch Accuracy: 0.3784
# Epoch 1/4, Batch Accuracy: 0.3783
# Epoch 1/4, Batch Accuracy: 0.3778
# Epoch 1/4, Batch Accuracy: 0.3778
# Epoch 1/4, Batch Accuracy: 0.3778
# Epoch 1/4, Batch Accuracy: 0.3782
# Epoch 1/4, Batch Accuracy: 0.3787
# Epoch 1/4, Batch Accuracy: 0.3786
# Epoch 1/4, Batch Accuracy: 0.3791
# Epoch 1/4, Batch Accuracy: 0.3795
# Epoch 1/4, Batch Accuracy: 0.3808
# Epoch 1/4, Batch Accuracy: 0.3812
# Epoch 1/4, Batch Accuracy: 0.3807
# Epoch 1/4, Batch Accuracy: 0.3811
# Epoch 1/4, Batch Accuracy: 0.3819
# Epoch 1/4, Batch Accuracy: 0.3815
# Epoch 1/4, Batch Accuracy: 0.3814
# Epoch 1/4, Batch Accuracy: 0.3822
# Epoch 1/4, Batch Accuracy: 0.3843
# Epoch 1/4, Batch Accuracy: 0.3855
# Epoch 1/4, Batch Accuracy: 0.3858
# Epoch 1/4, Batch Accuracy: 0.3866
# Epoch 1/4, Batch Accuracy: 0.3890
# Epoch 1/4, Batch Accuracy: 0.3897
# Epoch 1/4, Batch Accuracy: 0.3908
# Epoch 1/4, Batch Accuracy: 0.3923
# Epoch 1/4, Batch Accuracy: 0.3930
# Epoch 1/4, Batch Accuracy: 0.3937
# Epoch 1/4, Batch Accuracy: 0.3940
# Epoch 1/4, Batch Accuracy: 0.3950
# Epoch 1/4, Batch Accuracy: 0.3953
# Epoch 1/4, Batch Accuracy: 0.3960
# Epoch 1/4, Batch Accuracy: 0.3962
# Epoch 1/4, Batch Accuracy: 0.3961
# Epoch 1/4, Batch Accuracy: 0.3956
# Epoch 1/4, Batch Accuracy: 0.3966
# Epoch 1/4, Batch Accuracy: 0.3976
# Epoch 1/4, Batch Accuracy: 0.3971
# Epoch 1/4, Batch Accuracy: 0.3962
# Epoch 1/4, Batch Accuracy: 0.3950
# Epoch 1/4, Batch Accuracy: 0.3949
# Epoch 1/4, Batch Accuracy: 0.3958
# Epoch 1/4, Batch Accuracy: 0.3961
# Epoch 1/4, Batch Accuracy: 0.3967
# Epoch 1/4, Batch Accuracy: 0.3969
# Epoch 1/4, Batch Accuracy: 0.3975
# Epoch 1/4, Batch Accuracy: 0.3974
# Epoch 1/4, Batch Accuracy: 0.3980
# Epoch 1/4, Batch Accuracy: 0.3999
# Epoch 1/4, Batch Accuracy: 0.4008
# Epoch 1/4, Batch Accuracy: 0.4017
# Epoch 1/4, Batch Accuracy: 0.4037
# Epoch 1/4, Batch Accuracy: 0.4028
# Epoch 1/4, Batch Accuracy: 0.4040
# Epoch 1/4, Batch Accuracy: 0.4042
# Epoch 1/4, Batch Accuracy: 0.4037
# Epoch 1/4, Batch Accuracy: 0.4052
# Epoch 1/4, Batch Accuracy: 0.4061
# Epoch 1/4, Batch Accuracy: 0.4079
# Epoch 1/4, Batch Accuracy: 0.4074
# Epoch 1/4, Batch Accuracy: 0.4086
# Epoch 1/4, Batch Accuracy: 0.4090
# Epoch 1/4, Batch Accuracy: 0.4082
# Epoch 1/4, Batch Accuracy: 0.4093
# Epoch 1/4, Batch Accuracy: 0.4098
# Epoch 1/4, Batch Accuracy: 0.4099
# Epoch 1/4, Batch Accuracy: 0.4101
# Epoch 1/4, Batch Accuracy: 0.4102
# Epoch 1/4, Batch Accuracy: 0.4110
# Epoch 1/4, Batch Accuracy: 0.4111
# Epoch 1/4, Batch Accuracy: 0.4131
# Epoch 1/4, Batch Accuracy: 0.4136
# Epoch 1/4, Batch Accuracy: 0.4127
# Epoch 1/4, Batch Accuracy: 0.4129
# Epoch 1/4, Batch Accuracy: 0.4127
# Epoch 1/4, Batch Accuracy: 0.4131
# Epoch 1/4, Batch Accuracy: 0.4141
# Epoch 1/4, Batch Accuracy: 0.4161
# Epoch 1/4, Batch Accuracy: 0.4171
# Epoch 1/4, Batch Accuracy: 0.4169
# Epoch 1/4, Batch Accuracy: 0.4176
# Epoch 1/4, Batch Accuracy: 0.4177
# Epoch 1/4, Batch Accuracy: 0.4186
# Epoch 1/4, Batch Accuracy: 0.4181
# Epoch 1/4, Batch Accuracy: 0.4182
# Epoch 1/4, Batch Accuracy: 0.4186
# Epoch 1/4, Batch Accuracy: 0.4184
# Epoch 1/4, Batch Accuracy: 0.4191
# Epoch 1/4, Batch Accuracy: 0.4200
# Epoch 1/4, Batch Accuracy: 0.4215
# Epoch 1/4, Batch Accuracy: 0.4219
# Epoch 1/4, Batch Accuracy: 0.4228
# Epoch 1/4, Batch Accuracy: 0.4243
# Epoch 1/4, Batch Accuracy: 0.4246
# Epoch 1/4, Batch Accuracy: 0.4255
# Epoch 1/4, Batch Accuracy: 0.4261
# Epoch 1/4, Batch Accuracy: 0.4267
# Epoch 1/4, Batch Accuracy: 0.4273
# Epoch 1/4, Batch Accuracy: 0.4285
# Epoch 1/4, Batch Accuracy: 0.4279
# Epoch 1/4, Batch Accuracy: 0.4293
# Epoch 1/4, Batch Accuracy: 0.4302
# Epoch 1/4, Batch Accuracy: 0.4305
# Epoch 1/4, Batch Accuracy: 0.4308
# Epoch 1/4, Batch Accuracy: 0.4316
# Epoch 1/4, Batch Accuracy: 0.4322
# Epoch 1/4, Batch Accuracy: 0.4341
# Epoch 1/4, Batch Accuracy: 0.4354
# Epoch 1/4, Batch Accuracy: 0.4357
# Epoch 1/4, Batch Accuracy: 0.4359
# Epoch 1/4, Batch Accuracy: 0.4362
# Epoch 1/4, Batch Accuracy: 0.4370
# Epoch 1/4, Batch Accuracy: 0.4385
# Epoch 1/4, Batch Accuracy: 0.4396
# Epoch 1/4, Batch Accuracy: 0.4403
# Epoch 1/4, Batch Accuracy: 0.4413
# Epoch 1/4, Batch Accuracy: 0.4421
# Epoch 1/4, Batch Accuracy: 0.4431
# Epoch 1/4, Batch Accuracy: 0.4435
# Epoch 1/4, Batch Accuracy: 0.4440
# Epoch 1/4, Batch Accuracy: 0.4452
# Epoch 1/4, Batch Accuracy: 0.4462
# Epoch 1/4, Batch Accuracy: 0.4467
# Epoch 1/4, Batch Accuracy: 0.4476
# Epoch 1/4, Batch Accuracy: 0.4476
# Epoch 1/4, Batch Accuracy: 0.4478
# Epoch 1/4, Batch Accuracy: 0.4480
# Epoch 1/4, Batch Accuracy: 0.4482
# Epoch 1/4, Batch Accuracy: 0.4489
# Epoch 1/4, Batch Accuracy: 0.4491
# Epoch 1/4, Batch Accuracy: 0.4498
# Epoch 1/4, Batch Accuracy: 0.4507
# Epoch 1/4, Batch Accuracy: 0.4509
# Epoch 1/4, Batch Accuracy: 0.4510
# Epoch 1/4, Batch Accuracy: 0.4519
# Epoch 1/4, Batch Accuracy: 0.4524
# Epoch 1/4, Batch Accuracy: 0.4528
# Epoch 1/4, Batch Accuracy: 0.4534
# Epoch 1/4, Batch Accuracy: 0.4541
# Epoch 1/4, Batch Accuracy: 0.4549
# Epoch 1/4, Batch Accuracy: 0.4549
# Epoch 1/4, Batch Accuracy: 0.4557
# Epoch 1/4, Batch Accuracy: 0.4568
# Epoch 1/4, Batch Accuracy: 0.4576
# Epoch 1/4, Batch Accuracy: 0.4580
# Epoch 1/4, Batch Accuracy: 0.4582
# Epoch 1/4, Batch Accuracy: 0.4592
# Epoch 1/4, Batch Accuracy: 0.4603
# Epoch 1/4, Batch Accuracy: 0.4602
# Epoch 1/4, Batch Accuracy: 0.4599
# Epoch 1/4, Batch Accuracy: 0.4612
# Epoch 1/4, Batch Accuracy: 0.4624
# Epoch 1/4, Batch Accuracy: 0.4632
# Epoch 1/4, Batch Accuracy: 0.4633
# Epoch 1/4, Batch Accuracy: 0.4632
# Epoch 1/4, Batch Accuracy: 0.4638
# Epoch 1/4, Batch Accuracy: 0.4644
# Epoch 1/4, Batch Accuracy: 0.4643
# Epoch 1/4, Batch Accuracy: 0.4657
# Epoch 1/4, Batch Accuracy: 0.4660
# Epoch 1/4, Batch Accuracy: 0.4659
# Epoch 1/4, Batch Accuracy: 0.4661
# Epoch 1/4, Batch Accuracy: 0.4666
# Epoch 1/4, Batch Accuracy: 0.4663
# Epoch 1/4, Batch Accuracy: 0.4670
# Epoch 1/4, Batch Accuracy: 0.4678
# Epoch 1/4, Batch Accuracy: 0.4685
# Epoch 1/4, Batch Accuracy: 0.4693
# Epoch 1/4, Batch Accuracy: 0.4694
# Epoch 1/4, Batch Accuracy: 0.4697
# Epoch 1/4, Batch Accuracy: 0.4708
# Epoch 1/4, Batch Accuracy: 0.4713
# Epoch 1/4, Batch Accuracy: 0.4712
# Epoch 1/4, Batch Accuracy: 0.4719
# Epoch 1/4, Batch Accuracy: 0.4727
# Epoch 1/4, Batch Accuracy: 0.4725
# Epoch 1/4, Batch Accuracy: 0.4730
# Epoch 1/4, Batch Accuracy: 0.4731
# Epoch 1/4, Batch Accuracy: 0.4738
# Epoch 1/4, Batch Accuracy: 0.4741
# Epoch 1/4, Batch Accuracy: 0.4744
# Epoch 1/4, Batch Accuracy: 0.4747
# Epoch 1/4, Batch Accuracy: 0.4752
# Epoch 1/4, Batch Accuracy: 0.4762
# Epoch 1/4, Batch Accuracy: 0.4765
# Epoch 1/4, Batch Accuracy: 0.4772
# Epoch 1/4, Batch Accuracy: 0.4775
# Epoch 1/4, Batch Accuracy: 0.4775
# Epoch 1/4, Batch Accuracy: 0.4778
# Epoch 1/4, Batch Accuracy: 0.4784
# Epoch 1/4, Batch Accuracy: 0.4793
# Epoch 1/4, Batch Accuracy: 0.4801
# Epoch 1/4, Batch Accuracy: 0.4804
# Epoch 1/4, Batch Accuracy: 0.4807
# Epoch 1/4, Batch Accuracy: 0.4813
# Epoch 1/4, Batch Accuracy: 0.4815
# Epoch 1/4, Batch Accuracy: 0.4820
# Epoch 1/4, Batch Accuracy: 0.4828
# Epoch 1/4, Batch Accuracy: 0.4830
# Epoch 1/4, Batch Accuracy: 0.4831
# Epoch 1/4, Batch Accuracy: 0.4839
# Epoch 1/4, Batch Accuracy: 0.4847
# Epoch 1/4, Batch Accuracy: 0.4857
# Epoch 1/4, Batch Accuracy: 0.4861
# Epoch 1/4, Batch Accuracy: 0.4865
# Epoch 1/4, Batch Accuracy: 0.4869
# Epoch 1/4, Batch Accuracy: 0.4875
# Epoch 1/4, Batch Accuracy: 0.4881
# Epoch 1/4, Batch Accuracy: 0.4885
# Epoch 1/4, Batch Accuracy: 0.4895
# Epoch 1/4, Batch Accuracy: 0.4895
# Epoch 1/4, Batch Accuracy: 0.4905
# Epoch 1/4, Batch Accuracy: 0.4905
# Epoch 1/4, Batch Accuracy: 0.4907
# Epoch 1/4, Batch Accuracy: 0.4913
# Epoch 1/4, Batch Accuracy: 0.4909
# Epoch 1/4, Batch Accuracy: 0.4911
# Epoch 1/4, Batch Accuracy: 0.4917
# Epoch 1/4, Batch Accuracy: 0.4923
# Epoch 1/4, Batch Accuracy: 0.4927
# Epoch 1/4, Batch Accuracy: 0.4934
# Epoch 1/4, Batch Accuracy: 0.4939
# Epoch 1/4, Batch Accuracy: 0.4941
# Epoch 1/4, Batch Accuracy: 0.4952
# Epoch 1/4, Batch Accuracy: 0.4954
# Epoch 1/4, Batch Accuracy: 0.4961
# Epoch 1/4, Batch Accuracy: 0.4961
# Epoch 1/4, Batch Accuracy: 0.4961
# Epoch 1/4, Batch Accuracy: 0.4960
# Epoch 1/4, Batch Accuracy: 0.4965
# Epoch 1/4, Batch Accuracy: 0.4967
# Epoch 1/4, Batch Accuracy: 0.4967
# Epoch 1/4, Batch Accuracy: 0.4967
# Epoch 1/4, Batch Accuracy: 0.4974
# Epoch 1/4, Batch Accuracy: 0.4981
# Epoch 1/4, Batch Accuracy: 0.4986
# Epoch 1/4, Batch Accuracy: 0.4988
# Epoch 1/4, Batch Accuracy: 0.4985
# Epoch 1/4, Batch Accuracy: 0.4986
# Epoch 1/4, Batch Accuracy: 0.4992
# Epoch 1/4, Batch Accuracy: 0.4998
# Epoch 1/4, Batch Accuracy: 0.4993
# Epoch 1/4, Batch Accuracy: 0.5000
# Epoch 1/4, Batch Accuracy: 0.5002
# Epoch 1/4, Batch Accuracy: 0.5005
# Epoch 1/4, Batch Accuracy: 0.5012
# Epoch 1/4, Batch Accuracy: 0.5018
# Epoch 1/4, Batch Accuracy: 0.5020
# Epoch 1/4, Batch Accuracy: 0.5026
# Epoch 1/4, Batch Accuracy: 0.5033
# Epoch 1/4, Batch Accuracy: 0.5036
# Epoch 1/4, Batch Accuracy: 0.5038
# Epoch 1/4, Batch Accuracy: 0.5038
# Epoch 1/4, Batch Accuracy: 0.5041
# Epoch 1/4, Batch Accuracy: 0.5046
# Epoch 1/4, Batch Accuracy: 0.5052
# Epoch 1/4, Batch Accuracy: 0.5058
# Epoch 1/4, Batch Accuracy: 0.5063
# Epoch 1/4, Batch Accuracy: 0.5072
# Epoch 1/4, Batch Accuracy: 0.5071
# Epoch 1/4, Batch Accuracy: 0.5077
# Epoch 1/4, Batch Accuracy: 0.5072
# Epoch 1/4, Batch Accuracy: 0.5073
# Epoch 1/4, Batch Accuracy: 0.5080
# Epoch 1/4, Batch Accuracy: 0.5086
# Epoch 1/4, Batch Accuracy: 0.5085
# Epoch 1/4, Batch Accuracy: 0.5087
# Epoch 1/4, Batch Accuracy: 0.5094
# Epoch 1/4, Batch Accuracy: 0.5094
# Epoch 1/4, Batch Accuracy: 0.5096
# Epoch 1/4, Batch Accuracy: 0.5102
# Epoch 1/4, Batch Accuracy: 0.5106
# Epoch 1/4, Batch Accuracy: 0.5107
# Epoch 1/4, Batch Accuracy: 0.5112
# Epoch 1/4, Batch Accuracy: 0.5116
# Epoch 1/4, Batch Accuracy: 0.5120
# Epoch 1/4, Batch Accuracy: 0.5126
# Epoch 1/4, Batch Accuracy: 0.5131
# Epoch 1/4, Batch Accuracy: 0.5136
# Epoch 1/4, Batch Accuracy: 0.5141
# Epoch 1/4, Batch Accuracy: 0.5146
# Epoch 1/4, Batch Accuracy: 0.5146
# Epoch 1/4, Batch Accuracy: 0.5150
# Epoch 1/4, Batch Accuracy: 0.5159
# Epoch 1/4, Batch Accuracy: 0.5160
# Epoch 1/4, Batch Accuracy: 0.5161
# Epoch 1/4, Batch Accuracy: 0.5161
# Epoch 1/4, Batch Accuracy: 0.5160
# Epoch 1/4, Batch Accuracy: 0.5167
# Epoch 1/4, Batch Accuracy: 0.5175
# Epoch 1/4, Batch Accuracy: 0.5176
# Epoch 1/4, Batch Accuracy: 0.5180
# Epoch 1/4, Batch Accuracy: 0.5178
# Epoch 1/4, Batch Accuracy: 0.5180
# Epoch 1/4, Batch Accuracy: 0.5184
# Epoch 1/4, Batch Accuracy: 0.5191
# Epoch 1/4, Batch Accuracy: 0.5198
# Epoch 1/4, Batch Accuracy: 0.5196
# Epoch 1/4, Batch Accuracy: 0.5196
# Epoch 1/4, Batch Accuracy: 0.5201
# Epoch 1/4, Batch Accuracy: 0.5206
# Epoch 1/4, Batch Accuracy: 0.5212
# Epoch 1/4, Batch Accuracy: 0.5211
# Epoch 1/4, Batch Accuracy: 0.5212
# Epoch 1/4, Batch Accuracy: 0.5219
# Epoch 1/4, Batch Accuracy: 0.5218
# Epoch 1/4, Batch Accuracy: 0.5225
# Epoch 1/4, Batch Accuracy: 0.5229
# Epoch 1/4, Batch Accuracy: 0.5230
# Epoch 1/4, Batch Accuracy: 0.5233
# Epoch 1/4, Batch Accuracy: 0.5236
# Epoch 1/4, Batch Accuracy: 0.5244
# Epoch 1/4, Batch Accuracy: 0.5246
# Epoch 1/4, Batch Accuracy: 0.5250
# Epoch 1/4, Batch Accuracy: 0.5253
# Epoch 1/4, Batch Accuracy: 0.5256
# Epoch 1/4, Batch Accuracy: 0.5258
# Epoch 1/4, Batch Accuracy: 0.5264
# Epoch 1/4, Batch Accuracy: 0.5271
# Epoch 1/4, Batch Accuracy: 0.5274
# Epoch 1/4, Batch Accuracy: 0.5276
# Epoch 1/4, Batch Accuracy: 0.5277
# Epoch 1/4, Batch Accuracy: 0.5283
# Epoch 1/4, Batch Accuracy: 0.5288
# Epoch 1/4, Batch Accuracy: 0.5296
# Epoch 1/4, Batch Accuracy: 0.5298
# Epoch 1/4, Batch Accuracy: 0.5304
# Epoch 1/4, Batch Accuracy: 0.5308
# Epoch 1/4, Batch Accuracy: 0.5307
# Epoch 1/4, Batch Accuracy: 0.5310
# Epoch 1/4, Batch Accuracy: 0.5314
# Epoch 1/4, Batch Accuracy: 0.5317
# Epoch 1/4, Batch Accuracy: 0.5319
# Epoch 1/4, Batch Accuracy: 0.5323
# Epoch 1/4, Batch Accuracy: 0.5327
# Epoch 1/4, Batch Accuracy: 0.5333
# Epoch 1/4, Batch Accuracy: 0.5335
# Epoch 1/4, Batch Accuracy: 0.5336
# Epoch 1/4, Batch Accuracy: 0.5341
# Epoch 1/4, Batch Accuracy: 0.5342
# Epoch 1/4, Batch Accuracy: 0.5347
# Epoch 1/4, Batch Accuracy: 0.5353
# Epoch 1/4, Batch Accuracy: 0.5355
# Epoch 1/4, Batch Accuracy: 0.5357
# Epoch 1/4, Batch Accuracy: 0.5361
# Epoch 1/4, Batch Accuracy: 0.5368
# Epoch 1/4, Batch Accuracy: 0.5370
# Epoch 1/4, Batch Accuracy: 0.5373
# Epoch 1/4, Batch Accuracy: 0.5374
# Epoch 1/4, Batch Accuracy: 0.5380
# Epoch 1/4, Batch Accuracy: 0.5378
# Epoch 1/4, Batch Accuracy: 0.5379
# Epoch 1/4, Batch Accuracy: 0.5380
# Epoch 1/4, Batch Accuracy: 0.5387
# Epoch 1/4, Batch Accuracy: 0.5389
# Epoch 1/4, Batch Accuracy: 0.5388
# Epoch 1/4, Batch Accuracy: 0.5388
# Epoch 1/4, Batch Accuracy: 0.5397
# Epoch 1/4, Batch Accuracy: 0.5398
# Epoch 1/4, Batch Accuracy: 0.5401
# Epoch 1/4, Batch Accuracy: 0.5406
# Epoch 1/4, Batch Accuracy: 0.5412
# Epoch 1/4, Batch Accuracy: 0.5414
# Epoch 1/4, Batch Accuracy: 0.5417
# Epoch 1/4, Batch Accuracy: 0.5420
# Epoch 1/4, Batch Accuracy: 0.5422
# Epoch 1/4, Batch Accuracy: 0.5425
# Epoch 1/4, Batch Accuracy: 0.5428
# Epoch 1/4, Batch Accuracy: 0.5432
# Epoch 1/4, Batch Accuracy: 0.5437
# Epoch 1/4, Batch Accuracy: 0.5439
# Epoch 1/4, Batch Accuracy: 0.5442
# Epoch 1/4, Batch Accuracy: 0.5442
# Epoch 1/4, Batch Accuracy: 0.5446
# Epoch 1/4, Batch Accuracy: 0.5445
# Epoch 1/4, Batch Accuracy: 0.5447
# Epoch 1/4, Batch Accuracy: 0.5446
# Epoch 1/4, Batch Accuracy: 0.5450
# Epoch 1/4, Batch Accuracy: 0.5453
# Epoch 1/4, Batch Accuracy: 0.5459
# Epoch 1/4, Batch Accuracy: 0.5461
# Epoch 1/4, Batch Accuracy: 0.5465
# Epoch 1/4, Batch Accuracy: 0.5468
# Epoch 1/4, Batch Accuracy: 0.5473
# Epoch 1/4, Batch Accuracy: 0.5474
# Epoch 1/4, Batch Accuracy: 0.5477
# Epoch 1/4, Batch Accuracy: 0.5480
# Epoch 1/4, Batch Accuracy: 0.5486
# Epoch 1/4, Batch Accuracy: 0.5493
# Epoch 1/4, Batch Accuracy: 0.5497
# Epoch 1/4, Batch Accuracy: 0.5501
# Epoch 1/4, Batch Accuracy: 0.5506
# Epoch 1/4, Batch Accuracy: 0.5504
# Epoch 1/4, Batch Accuracy: 0.5508
# Epoch 1/4, Batch Accuracy: 0.5508
# Epoch 1/4, Batch Accuracy: 0.5508
# Epoch 1/4, Batch Accuracy: 0.5510
# Epoch 1/4, Batch Accuracy: 0.5514
# Epoch 1/4, Batch Accuracy: 0.5520
# Epoch 1/4, Batch Accuracy: 0.5523
# Epoch 1/4, Batch Accuracy: 0.5526
# Epoch 1/4, Batch Accuracy: 0.5531
# Epoch 1/4, Batch Accuracy: 0.5531
# Epoch 1/4, Batch Accuracy: 0.5532
# Epoch 1/4, Batch Accuracy: 0.5535
# Epoch 1/4, Batch Accuracy: 0.5537
# Epoch 1/4, Batch Accuracy: 0.5541
# Epoch 1/4, Batch Accuracy: 0.5542
# Epoch 1/4, Batch Accuracy: 0.5546
# Epoch 1/4, Batch Accuracy: 0.5551
# Epoch 1/4, Batch Accuracy: 0.5551
# Epoch 1/4, Batch Accuracy: 0.5555
# Epoch 1/4, Batch Accuracy: 0.5560
# Epoch 1/4, Batch Accuracy: 0.5564
# Epoch 1/4, Batch Accuracy: 0.5566
# Epoch 1/4, Batch Accuracy: 0.5569
# Epoch 1/4, Batch Accuracy: 0.5569
# Epoch 1/4, Batch Accuracy: 0.5570
# Epoch 1/4, Batch Accuracy: 0.5568
# Epoch 1/4, Batch Accuracy: 0.5571
# Epoch 1/4, Batch Accuracy: 0.5576
# Epoch 1/4, Batch Accuracy: 0.5577
# Epoch 1/4, Batch Accuracy: 0.5579
# Epoch 1/4, Batch Accuracy: 0.5578
# Epoch 1/4, Batch Accuracy: 0.5583
# Epoch 1/4, Batch Accuracy: 0.5589
# Epoch 1/4, Batch Accuracy: 0.5594
# Epoch 1/4, Batch Accuracy: 0.5595
# Epoch 1/4, Batch Accuracy: 0.5597
# Epoch 1/4, Batch Accuracy: 0.5598
# Epoch 1/4, Batch Accuracy: 0.5602
# Epoch 1/4, Batch Accuracy: 0.5606
# Epoch 1/4, Batch Accuracy: 0.5607
# Epoch 1/4, Batch Accuracy: 0.5611
# Epoch 1/4, Batch Accuracy: 0.5614
# Epoch 1/4, Batch Accuracy: 0.5613
# Epoch 1/4, Batch Accuracy: 0.5614
# Epoch 1/4, Batch Accuracy: 0.5614
# Epoch 1/4, Batch Accuracy: 0.5617
# Epoch 1/4, Batch Accuracy: 0.5621
# Epoch 1/4, Batch Accuracy: 0.5625
# Epoch 1/4, Batch Accuracy: 0.5626
# Epoch 1/4, Batch Accuracy: 0.5625
# Epoch 1/4, Batch Accuracy: 0.5627
# Epoch 1/4, Batch Accuracy: 0.5628
# Epoch 1/4, Batch Accuracy: 0.5632
# Epoch 1/4, Batch Accuracy: 0.5636
# Epoch 1/4, Batch Accuracy: 0.5639
# Epoch 1/4, Batch Accuracy: 0.5642
# Epoch 1/4, Batch Accuracy: 0.5646
# Epoch 1/4, Batch Accuracy: 0.5648
# Epoch 1/4, Batch Accuracy: 0.5652
# Epoch 1/4, Batch Accuracy: 0.5653
# Epoch 1/4, Batch Accuracy: 0.5653
# Epoch 1/4, Batch Accuracy: 0.5653
# Epoch 1/4, Batch Accuracy: 0.5658
# Epoch 1/4, Batch Accuracy: 0.5657
# Epoch 1/4, Batch Accuracy: 0.5656
# Epoch 1/4, Batch Accuracy: 0.5662
# Epoch 1/4, Batch Accuracy: 0.5664
# Epoch 1/4, Batch Accuracy: 0.5664
# Epoch 1/4, Batch Accuracy: 0.5668
# Epoch 1/4, Batch Accuracy: 0.5673
# Epoch 1/4, Batch Accuracy: 0.5673
# Epoch 1/4, Batch Accuracy: 0.5674
# Epoch 1/4, Batch Accuracy: 0.5679
# Epoch 1/4, Batch Accuracy: 0.5677
# Epoch 1/4, Batch Accuracy: 0.5679
# Epoch 1/4, Batch Accuracy: 0.5678
# Epoch 1/4, Batch Accuracy: 0.5680
# Epoch 1/4, Batch Accuracy: 0.5682
# Epoch 1/4, Batch Accuracy: 0.5682
# Epoch 1/4, Batch Accuracy: 0.5684
# Epoch 1/4, Batch Accuracy: 0.5688
# Epoch 1/4, Batch Accuracy: 0.5691
# Epoch 1/4, Batch Accuracy: 0.5696
# Epoch 1/4, Batch Accuracy: 0.5700
# Epoch 1/4, Batch Accuracy: 0.5702
# Epoch 1/4, Batch Accuracy: 0.5704
# Epoch 1/4, Batch Accuracy: 0.5709
# Epoch 1/4, Batch Accuracy: 0.5713
# Epoch 1/4, Batch Accuracy: 0.5712
# Epoch 1/4, Batch Accuracy: 0.5715
# Epoch 1/4, Batch Accuracy: 0.5717
# Epoch 1/4, Batch Accuracy: 0.5718
# Epoch 1/4, Batch Accuracy: 0.5717
# Epoch 1/4, Batch Accuracy: 0.5719
# Epoch 1/4, Batch Accuracy: 0.5724
# Epoch 1/4, Batch Accuracy: 0.5731
# Epoch 1/4, Batch Accuracy: 0.5733
# Epoch 1/4, Batch Accuracy: 0.5733
# Epoch 1/4, Batch Accuracy: 0.5735
# Epoch 1/4, Batch Accuracy: 0.5737
# Epoch 1/4, Batch Accuracy: 0.5738
# Epoch 1/4, Batch Accuracy: 0.5741
# Epoch 1/4, Batch Accuracy: 0.5743
# Epoch 1/4, Batch Accuracy: 0.5745
# Epoch 1/4, Batch Accuracy: 0.5750
# Epoch 1/4, Batch Accuracy: 0.5750
# Epoch 1/4, Batch Accuracy: 0.5751
# Epoch 1/4, Batch Accuracy: 0.5752
# Epoch 1/4, Batch Accuracy: 0.5757
# Epoch 1/4, Batch Accuracy: 0.5758
# Epoch 1/4, Batch Accuracy: 0.5758
# Epoch 1/4, Batch Accuracy: 0.5763
# Epoch 1/4, Batch Accuracy: 0.5765
# Epoch 1/4, Batch Accuracy: 0.5767
# Epoch 1/4, Batch Accuracy: 0.5768
# Epoch 1/4, Batch Accuracy: 0.5769
# Epoch 1/4, Batch Accuracy: 0.5771
# Epoch 1/4, Batch Accuracy: 0.5772
# Epoch 1/4, Batch Accuracy: 0.5774
# Epoch 1/4, Batch Accuracy: 0.5777
# Epoch 1/4, Batch Accuracy: 0.5780
# Epoch 1/4, Batch Accuracy: 0.5782
# Epoch 1/4, Batch Accuracy: 0.5785
# Epoch 1/4, Batch Accuracy: 0.5787
# Epoch 1/4, Batch Accuracy: 0.5790
# Epoch 1/4, Batch Accuracy: 0.5794
# Epoch 1/4, Batch Accuracy: 0.5799
# Epoch 1/4, Batch Accuracy: 0.5803
# Epoch 1/4, Batch Accuracy: 0.5805
# Epoch 1/4, Batch Accuracy: 0.5806
# Epoch 1/4, Batch Accuracy: 0.5807
# Epoch 1/4, Batch Accuracy: 0.5810
# Epoch 1/4, Batch Accuracy: 0.5814
# Epoch 1/4, Batch Accuracy: 0.5816
# Epoch 1/4, Batch Accuracy: 0.5818
# Epoch 1/4, Batch Accuracy: 0.5818
# Epoch 1/4, Batch Accuracy: 0.5822
# Epoch 1/4, Batch Accuracy: 0.5820
# Epoch 1/4, Batch Accuracy: 0.5822
# Epoch 1/4, Batch Accuracy: 0.5824
# Epoch 1/4, Batch Accuracy: 0.5823
# Epoch 1/4, Batch Accuracy: 0.5823
# Epoch 1/4, Batch Accuracy: 0.5826
# Epoch 1/4, Batch Accuracy: 0.5830
# Epoch 1/4, Batch Accuracy: 0.5827
# Epoch 1/4, Batch Accuracy: 0.5828
# Epoch 1/4, Batch Accuracy: 0.5830
# Epoch 1/4, Batch Accuracy: 0.5833
# Epoch 1/4, Batch Accuracy: 0.5835
# Epoch 1/4, Batch Accuracy: 0.5834
# Epoch 1/4, Batch Accuracy: 0.5834
# Epoch 1/4, Batch Accuracy: 0.5837
# Epoch 1/4, Batch Accuracy: 0.5843
# Epoch 1/4, Batch Accuracy: 0.5843
# Epoch 1/4, Batch Accuracy: 0.5844
# Epoch 1/4, Batch Accuracy: 0.5845
# Epoch 1/4, Batch Accuracy: 0.5847
# Epoch 1/4, Batch Accuracy: 0.5847
# Epoch 1/4, Batch Accuracy: 0.5850
# Epoch 1/4, Batch Accuracy: 0.5853
# Epoch 1/4, Batch Accuracy: 0.5855
# Epoch 1/4, Batch Accuracy: 0.5856
# Epoch 1/4, Batch Accuracy: 0.5858
# Epoch 1/4, Batch Accuracy: 0.5858
# Epoch 1/4, Batch Accuracy: 0.5862
# Epoch 1/4, Batch Accuracy: 0.5860
# Epoch 1/4, Batch Accuracy: 0.5861
# Epoch 1/4, Batch Accuracy: 0.5860
# Epoch 1/4, Batch Accuracy: 0.5865
# Epoch 1/4, Batch Accuracy: 0.5867
# Epoch 1/4, Batch Accuracy: 0.5866
# Epoch 1/4, Batch Accuracy: 0.5865
# Epoch 1/4, Batch Accuracy: 0.5870
# Epoch 1/4, Batch Accuracy: 0.5875
# Epoch 1/4, Batch Accuracy: 0.5875
# Epoch 1/4, Batch Accuracy: 0.5878
# Epoch 1/4, Batch Accuracy: 0.5882
# Epoch 1/4, Batch Accuracy: 0.5885
# Epoch 1/4, Batch Accuracy: 0.5884
# Epoch 1/4, Batch Accuracy: 0.5883
# Epoch 1/4, Batch Accuracy: 0.5885
# Epoch 1/4, Batch Accuracy: 0.5890
# Epoch 1/4, Batch Accuracy: 0.5888
# Epoch 1/4, Batch Accuracy: 0.5892
# Epoch 1/4, Batch Accuracy: 0.5894
# Epoch 1/4, Batch Accuracy: 0.5898
# Epoch 1/4, Batch Accuracy: 0.5900
# Epoch 1/4, Batch Accuracy: 0.5902
# Epoch 1/4, Batch Accuracy: 0.5903
# Epoch 1/4, Batch Accuracy: 0.5905
# Epoch 1/4, Batch Accuracy: 0.5906
# Epoch 1/4, Batch Accuracy: 0.5907
# Epoch 1/4, Batch Accuracy: 0.5909
# Epoch 1/4, Batch Accuracy: 0.5910
# Epoch 1/4, Batch Accuracy: 0.5911
# Epoch 1/4, Batch Accuracy: 0.5911
# Epoch 1/4, Batch Accuracy: 0.5913
# Epoch 1/4, Batch Accuracy: 0.5915
# Epoch 1/4, Batch Accuracy: 0.5916
# Epoch 1/4, Batch Accuracy: 0.5918
# Epoch 1/4, Batch Accuracy: 0.5918
# Epoch 1/4, Batch Accuracy: 0.5919
# Epoch 1/4, Batch Accuracy: 0.5924
# Epoch 1/4, Batch Accuracy: 0.5925
# Epoch 1/4, Batch Accuracy: 0.5924
# Epoch 1/4, Batch Accuracy: 0.5927
# Epoch 1/4, Batch Accuracy: 0.5929
# Epoch 1/4, Batch Accuracy: 0.5930
# Epoch 1/4, Batch Accuracy: 0.5932
# Epoch 1/4, Batch Accuracy: 0.5934
# Epoch 1/4, Batch Accuracy: 0.5936
# Epoch 1/4, Batch Accuracy: 0.5938
# Epoch 1/4, Batch Accuracy: 0.5937
# Epoch 1/4, Batch Accuracy: 0.5938
# Epoch 1/4, Batch Accuracy: 0.5942
# Epoch 1/4, Batch Accuracy: 0.5940
# Epoch 1/4, Batch Accuracy: 0.5940
# Epoch 1/4, Batch Accuracy: 0.5943
# Epoch 1/4, Batch Accuracy: 0.5944
# Epoch 1/4, Batch Accuracy: 0.5947
# Epoch 1/4, Batch Accuracy: 0.5948
# Epoch 1/4, Batch Accuracy: 0.5949
# Epoch 1/4, Batch Accuracy: 0.5951
# Epoch 1/4, Batch Accuracy: 0.5952
# Epoch 1/4, Batch Accuracy: 0.5951
# Epoch 1/4, Batch Accuracy: 0.5951
# Epoch 1/4, Batch Accuracy: 0.5950
# Epoch 1/4, Batch Accuracy: 0.5951
# Epoch 1/4, Batch Accuracy: 0.5950
# Epoch 1/4, Batch Accuracy: 0.5953
# Epoch 1/4, Batch Accuracy: 0.5956
# Epoch 1/4, Batch Accuracy: 0.5956
# Epoch 1/4, Batch Accuracy: 0.5959
# Epoch 1/4, Batch Accuracy: 0.5960
# Epoch 1/4, Batch Accuracy: 0.5961
# Epoch 1/4, Batch Accuracy: 0.5963
# Epoch 1/4, Batch Accuracy: 0.5964
# Epoch 1/4, Batch Accuracy: 0.5966
# Epoch 1/4, Batch Accuracy: 0.5969
# Epoch 1/4, Batch Accuracy: 0.5971
# Epoch 1/4, Batch Accuracy: 0.5974
# Epoch 1/4, Batch Accuracy: 0.5976
# Epoch 1/4, Batch Accuracy: 0.5980
# Epoch 1/4, Batch Accuracy: 0.5982
# Epoch 1/4, Batch Accuracy: 0.5984
# Epoch 1/4, Batch Accuracy: 0.5984
# Epoch 1/4, Batch Accuracy: 0.5987
# Epoch 1/4, Batch Accuracy: 0.5989
# Epoch 1/4, Batch Accuracy: 0.5991
# Epoch 1/4, Batch Accuracy: 0.5990
# Epoch 1/4, Batch Accuracy: 0.5991
# Epoch 1/4, Batch Accuracy: 0.5995
# Epoch 1/4, Batch Accuracy: 0.5995
# Epoch 1/4, Batch Accuracy: 0.5998
# Epoch 1/4, Batch Accuracy: 0.6001
# Epoch 1/4, Batch Accuracy: 0.6003
# Epoch 1/4, Batch Accuracy: 0.6004
# Epoch 1/4, Batch Accuracy: 0.6005
# Epoch 1/4, Batch Accuracy: 0.6008
# Epoch 1/4, Batch Accuracy: 0.6010
# Epoch 1/4, Batch Accuracy: 0.6013
# Epoch 1/4, Batch Accuracy: 0.6013
# Epoch 1/4, Batch Accuracy: 0.6015
# Epoch 1/4, Batch Accuracy: 0.6017
# Epoch 1/4, Batch Accuracy: 0.6020
# Epoch 1/4, Batch Accuracy: 0.6021
# Epoch 1/4, Batch Accuracy: 0.6022
# Epoch 1/4, Batch Accuracy: 0.6025
# Epoch 1/4, Batch Accuracy: 0.6029
# Epoch 1/4, Batch Accuracy: 0.6031
# Epoch 1/4, Batch Accuracy: 0.6029
# Epoch 1/4, Batch Accuracy: 0.6029
# Epoch 1/4, Batch Accuracy: 0.6031
# Epoch 1/4, Batch Accuracy: 0.6030
# Epoch 1/4, Batch Accuracy: 0.6030
# Epoch 1/4, Batch Accuracy: 0.6032
# Epoch 1/4, Batch Accuracy: 0.6034
# Epoch 1/4, Batch Accuracy: 0.6036
# Epoch 1/4, Batch Accuracy: 0.6039
# Epoch 1/4, Batch Accuracy: 0.6041
# Epoch 1/4, Batch Accuracy: 0.6041
# Epoch 1/4, Batch Accuracy: 0.6044
# Epoch 1/4, Batch Accuracy: 0.6047
# Epoch 1/4, Batch Accuracy: 0.6047
# Epoch 1/4, Batch Accuracy: 0.6046
# Epoch 1/4, Batch Accuracy: 0.6048
# Epoch 1/4, Batch Accuracy: 0.6050
# Epoch 1/4, Batch Accuracy: 0.6051
# Epoch 1/4, Batch Accuracy: 0.6054
# Epoch 1/4, Batch Accuracy: 0.6055
# Epoch 1/4, Batch Accuracy: 0.6057
# Epoch 1/4, Batch Accuracy: 0.6058
# Epoch 1/4, Batch Accuracy: 0.6060
# Epoch 1/4, Batch Accuracy: 0.6059
# Epoch 1/4, Batch Accuracy: 0.6059
# Epoch 1/4, Batch Accuracy: 0.6061
# Epoch 1/4, Batch Accuracy: 0.6062
# Epoch 1/4, Batch Accuracy: 0.6063
# Epoch 1/4, Batch Accuracy: 0.6065
# Epoch 1/4, Batch Accuracy: 0.6067
# Epoch 1/4, Batch Accuracy: 0.6068
# Epoch 1/4, Batch Accuracy: 0.6070
# Epoch 1/4, Batch Accuracy: 0.6073
# Epoch 1/4, Batch Accuracy: 0.6073
# Epoch 1/4, Batch Accuracy: 0.6072
# Epoch 1/4, Batch Accuracy: 0.6073
# Epoch 1/4, Batch Accuracy: 0.6077
# Epoch 1/4, Batch Accuracy: 0.6079
# Epoch 1/4, Batch Accuracy: 0.6082
# Epoch 1/4, Batch Accuracy: 0.6082
# Epoch 1/4, Batch Accuracy: 0.6083
# Epoch 1/4, Batch Accuracy: 0.6082
# Epoch 1/4, Batch Accuracy: 0.6083
# Epoch 1/4, Batch Accuracy: 0.6086
# Epoch 1/4, Batch Accuracy: 0.6086
# Epoch 1/4, Batch Accuracy: 0.6087
# Epoch 1/4, Batch Accuracy: 0.6088
# Epoch 1/4, Batch Accuracy: 0.6089
# Epoch 1/4, Batch Accuracy: 0.6091
# Epoch 1/4, Batch Accuracy: 0.6092
# Epoch 1/4, Batch Accuracy: 0.6096
# Epoch 1/4, Batch Accuracy: 0.6097
# Epoch 1/4, Batch Accuracy: 0.6100
# Epoch 1/4, Batch Accuracy: 0.6099
# Epoch 1/4, Batch Accuracy: 0.6101
# Epoch 1/4, Batch Accuracy: 0.6103
# Epoch 1/4, Batch Accuracy: 0.6102
# Epoch 1/4, Batch Accuracy: 0.6104
# Epoch 1/4, Batch Accuracy: 0.6105
# Epoch 1/4, Batch Accuracy: 0.6107
# Epoch 1/4, Batch Accuracy: 0.6109
# Epoch 1/4, Batch Accuracy: 0.6110
# Epoch 1/4, Batch Accuracy: 0.6112
# Epoch 1/4, Batch Accuracy: 0.6112
# Epoch 1/4, Batch Accuracy: 0.6111
# Epoch 1/4, Batch Accuracy: 0.6112
# Epoch 1/4, Batch Accuracy: 0.6114
# Epoch 1/4, Batch Accuracy: 0.6116
# Epoch 1/4, Batch Accuracy: 0.6118
# Epoch 1/4, Batch Accuracy: 0.6120
# Epoch 1/4, Batch Accuracy: 0.6121
# Epoch 1/4, Batch Accuracy: 0.6121
# Epoch 1/4, Batch Accuracy: 0.6122
# Epoch 1/4, Batch Accuracy: 0.6125
# Epoch 1/4, Batch Accuracy: 0.6127
# Epoch 1/4, Batch Accuracy: 0.6130
# Epoch 1/4, Batch Accuracy: 0.6131
# Epoch 1/4, Batch Accuracy: 0.6133
# Epoch 1/4, Batch Accuracy: 0.6134
# Epoch 1/4, Batch Accuracy: 0.6136
# Epoch 1/4, Batch Accuracy: 0.6136
# Epoch 1/4, Batch Accuracy: 0.6140
# Epoch 1/4, Batch Accuracy: 0.6140
# Epoch 1/4, Batch Accuracy: 0.6144
# Epoch 1/4, Batch Accuracy: 0.6146
# Epoch 1/4, Batch Accuracy: 0.6149
# Epoch 1/4, Batch Accuracy: 0.6150
# Epoch 1/4, Batch Accuracy: 0.6152
# Epoch 1/4, Batch Accuracy: 0.6153
# Epoch 1/4, Batch Accuracy: 0.6154
# Epoch 1/4, Batch Accuracy: 0.6157
# Epoch 1/4, Batch Accuracy: 0.6157
# Epoch 1/4, Batch Accuracy: 0.6157
# Epoch 1/4, Batch Accuracy: 0.6155
# Epoch 1/4, Batch Accuracy: 0.6156
# Epoch 1/4, Batch Accuracy: 0.6159
# Epoch 1/4, Batch Accuracy: 0.6160
# Epoch 1/4, Batch Accuracy: 0.6159
# Epoch 1/4, Batch Accuracy: 0.6162
# Epoch 1/4, Batch Accuracy: 0.6164
# Epoch 1/4, Batch Accuracy: 0.6164
# Epoch 1/4, Batch Accuracy: 0.6165
# Epoch 1/4, Batch Accuracy: 0.6163
# Epoch 1/4, Batch Accuracy: 0.6164
# Epoch 1/4, Batch Accuracy: 0.6164
# Epoch 1/4, Batch Accuracy: 0.6164
# Epoch 1/4, Batch Accuracy: 0.6164
# Epoch 1/4, Batch Accuracy: 0.6167
# Epoch 1/4, Batch Accuracy: 0.6169
# Epoch 1/4, Batch Accuracy: 0.6168
# Epoch 1/4, Batch Accuracy: 0.6170
# Epoch 1/4, Batch Accuracy: 0.6172
# Epoch 1/4, Batch Accuracy: 0.6173
# Epoch 1/4, Batch Accuracy: 0.6173
# Epoch 1/4, Batch Accuracy: 0.6176
# Epoch 1/4, Batch Accuracy: 0.6177
# Epoch 1/4, Batch Accuracy: 0.6178
# Epoch 1/4, Batch Accuracy: 0.6180
# Epoch 1/4, Batch Accuracy: 0.6183
# Epoch 1/4, Batch Accuracy: 0.6186
# Epoch 1/4, Batch Accuracy: 0.6188
# Epoch 1/4, Batch Accuracy: 0.6191
# Epoch 1/4, Batch Accuracy: 0.6189
# Epoch 1/4, Batch Accuracy: 0.6192
# Epoch 1/4, Batch Accuracy: 0.6195
# Epoch 1/4, Batch Accuracy: 0.6193
# Epoch 1/4, Batch Accuracy: 0.6194
# Epoch 1/4, Batch Accuracy: 0.6194
# Epoch 1/4, Batch Accuracy: 0.6195
# Epoch 1/4, Batch Accuracy: 0.6195
# Epoch 1/4, Batch Accuracy: 0.6195
# Epoch 1/4, Batch Accuracy: 0.6196
# Epoch 1/4, Batch Accuracy: 0.6197
# Epoch 1/4, Batch Accuracy: 0.6200
# Epoch 1/4, Batch Accuracy: 0.6201
# Epoch 1/4, Batch Accuracy: 0.6205
# Epoch 1/4, Batch Accuracy: 0.6205
# Epoch 1/4, Batch Accuracy: 0.6205
# Epoch 1/4, Batch Accuracy: 0.6202
# Epoch 1/4, Batch Accuracy: 0.6205
# Epoch 1/4, Batch Accuracy: 0.6207
# Epoch 1/4, Batch Accuracy: 0.6209
# Epoch 1/4, Batch Accuracy: 0.6209
# Epoch 1/4, Batch Accuracy: 0.6209
# Epoch 1/4, Batch Accuracy: 0.6212
# Epoch 1/4, Batch Accuracy: 0.6214
# Epoch 1/4, Batch Accuracy: 0.6212
# Epoch 1/4, Batch Accuracy: 0.6213
# Epoch 1/4, Batch Accuracy: 0.6215
# Epoch 1/4, Batch Accuracy: 0.6215
# Epoch 1/4, Batch Accuracy: 0.6215
# Epoch 1/4, Batch Accuracy: 0.6216
# Epoch 1/4, Batch Accuracy: 0.6216
# Epoch 1/4, Batch Accuracy: 0.6218
# Epoch 1/4, Batch Accuracy: 0.6220
# Epoch 1/4, Batch Accuracy: 0.6223
# Epoch 1/4, Batch Accuracy: 0.6225
# Epoch 1/4, Batch Accuracy: 0.6225
# Epoch 1/4, Batch Accuracy: 0.6226
# Epoch 1/4, Batch Accuracy: 0.6229
# Epoch 1/4, Batch Accuracy: 0.6231
# Epoch 1/4, Batch Accuracy: 0.6232
# Epoch 1/4, Batch Accuracy: 0.6231
# Epoch 1/4, Batch Accuracy: 0.6232
# Epoch 1/4, Batch Accuracy: 0.6233
# Epoch 1/4, Batch Accuracy: 0.6233
# Epoch 1/4, Batch Accuracy: 0.6232
# Epoch 1/4, Batch Accuracy: 0.6234
# Epoch 1/4, Batch Accuracy: 0.6234
# Epoch 1/4, Batch Accuracy: 0.6238
# Epoch 1/4, Batch Accuracy: 0.6240
# Epoch 1/4, Batch Accuracy: 0.6242
# Epoch 1/4, Batch Accuracy: 0.6244
# Epoch 1/4, Batch Accuracy: 0.6245
# Epoch 1/4, Batch Accuracy: 0.6247
# Epoch 1/4, Batch Accuracy: 0.6247
# Epoch 1/4, Batch Accuracy: 0.6251
# Epoch 1/4, Batch Accuracy: 0.6253
# Epoch 1/4, Batch Accuracy: 0.6255
# Epoch 1/4, Batch Accuracy: 0.6255
# Epoch 1/4, Batch Accuracy: 0.6256
# Epoch 1/4, Batch Accuracy: 0.6256
# Epoch 1/4, Batch Accuracy: 0.6258
# Epoch 1/4, Batch Accuracy: 0.6261
# Epoch 1/4, Batch Accuracy: 0.6263
# Epoch 1/4, Batch Accuracy: 0.6264
# Epoch 1/4, Batch Accuracy: 0.6263
# Epoch 1/4, Batch Accuracy: 0.6264
# Epoch 1/4, Batch Accuracy: 0.6265
# Epoch 1/4, Batch Accuracy: 0.6267
# Epoch 1/4, Batch Accuracy: 0.6266
# Epoch 1/4, Batch Accuracy: 0.6267
# Epoch 1/4, Batch Accuracy: 0.6268
# Epoch 1/4, Batch Accuracy: 0.6268
# Epoch 1/4, Batch Accuracy: 0.6269
# Epoch 1/4, Batch Accuracy: 0.6272
# Epoch 1/4, Batch Accuracy: 0.6272
# Epoch 1/4, Batch Accuracy: 0.6273
# Epoch 1/4, Batch Accuracy: 0.6275
# Epoch 1/4, Batch Accuracy: 0.6277
# Epoch 1/4, Batch Accuracy: 0.6279
# Epoch 1/4, Batch Accuracy: 0.6280
# Epoch 1/4, Batch Accuracy: 0.6281
# Epoch 1/4, Batch Accuracy: 0.6283
# Epoch 1/4, Batch Accuracy: 0.6285
# Epoch 1/4, Batch Accuracy: 0.6286
# Epoch 1/4, Batch Accuracy: 0.6289
# Epoch 1/4, Batch Accuracy: 0.6290
# Epoch 1/4, Batch Accuracy: 0.6292
# Epoch 1/4, Batch Accuracy: 0.6291
# Epoch 1/4, Batch Accuracy: 0.6292
# Epoch 1/4, Batch Accuracy: 0.6294
# Epoch 1/4, Batch Accuracy: 0.6296
# Epoch 1/4, Batch Accuracy: 0.6297
# Epoch 1/4, Batch Accuracy: 0.6299
# Epoch 1/4, Batch Accuracy: 0.6298
# Epoch 1/4, Batch Accuracy: 0.6301
# Epoch 1/4, Batch Accuracy: 0.6302
# Epoch 1/4, Batch Accuracy: 0.6303
# Epoch 1/4, Batch Accuracy: 0.6304
# Epoch 1/4, Batch Accuracy: 0.6306
# Epoch 1/4, Batch Accuracy: 0.6307
# Epoch 1/4, Batch Accuracy: 0.6307
# Epoch 1/4, Batch Accuracy: 0.6309
# Epoch 1/4, Batch Accuracy: 0.6310
# Epoch 1/4, Batch Accuracy: 0.6311
# Epoch 1/4, Batch Accuracy: 0.6312
# Epoch 1/4, Batch Accuracy: 0.6315
# Epoch 1/4, Batch Accuracy: 0.6318
# Epoch 1/4, Batch Accuracy: 0.6320
# Epoch 1/4, Batch Accuracy: 0.6321
# Epoch 1/4, Batch Accuracy: 0.6322
# Epoch 1/4, Batch Accuracy: 0.6323
# Epoch 1/4, Batch Accuracy: 0.6325
# Epoch 1/4, Batch Accuracy: 0.6325
# Epoch 1/4, Batch Accuracy: 0.6324
# Epoch 1/4, Batch Accuracy: 0.6325
# Epoch 1/4, Batch Accuracy: 0.6328
# Epoch 1/4, Batch Accuracy: 0.6330
# Epoch 1/4, Batch Accuracy: 0.6330
# Epoch 1/4, Batch Accuracy: 0.6331
# Epoch 1/4, Batch Accuracy: 0.6333
# Epoch 1/4, Batch Accuracy: 0.6335
# Epoch 1/4, Batch Accuracy: 0.6334
# Epoch 1/4, Batch Accuracy: 0.6335
# Epoch 1/4, Batch Accuracy: 0.6336
# Epoch 1/4, Batch Accuracy: 0.6337
# Epoch 1/4, Batch Accuracy: 0.6336
# Epoch 1/4, Batch Accuracy: 0.6337
# Epoch 1/4, Batch Accuracy: 0.6339
# Epoch 1/4, Batch Accuracy: 0.6342
# Epoch 1/4, Batch Accuracy: 0.6343
# Epoch 1/4, Batch Accuracy: 0.6344
# Epoch 1/4, Batch Accuracy: 0.6343
# Epoch 1/4, Batch Accuracy: 0.6344
# Epoch 1/4, Batch Accuracy: 0.6345
# Epoch 1/4, Batch Accuracy: 0.6347
# Epoch 1/4, Batch Accuracy: 0.6348
# Epoch 1/4, Batch Accuracy: 0.6350
# Epoch 1/4, Batch Accuracy: 0.6350
# Epoch 1/4, Batch Accuracy: 0.6350
# Epoch 1/4, Batch Accuracy: 0.6351
# Epoch 1/4, Batch Accuracy: 0.6352
# Epoch 1/4, Batch Accuracy: 0.6352
# Epoch 1/4, Batch Accuracy: 0.6353
# Epoch 1/4, Batch Accuracy: 0.6355
# Epoch 1/4, Batch Accuracy: 0.6356
# Epoch 1/4, Batch Accuracy: 0.6357
# Epoch 1/4, Batch Accuracy: 0.6358
# Epoch 1/4, Batch Accuracy: 0.6360
# Epoch 1/4, Batch Accuracy: 0.6361
# Epoch 1/4, Batch Accuracy: 0.6360
# Epoch 1/4, Batch Accuracy: 0.6360
# Epoch 1/4, Batch Accuracy: 0.6360
# Epoch 1/4, Batch Accuracy: 0.6360
# Epoch 1/4, Batch Accuracy: 0.6360
# Epoch 1/4, Batch Accuracy: 0.6361
# Epoch 1/4, Batch Accuracy: 0.6363
# Epoch 1/4, Batch Accuracy: 0.6365
# Epoch 1/4, Batch Accuracy: 0.6365
# Epoch 1/4, Batch Accuracy: 0.6366
# Epoch 1/4, Batch Accuracy: 0.6366
# Epoch 1/4, Batch Accuracy: 0.6369
# Epoch 1/4, Batch Accuracy: 0.6368
# Epoch 1/4, Batch Accuracy: 0.6370
# Epoch 1/4, Batch Accuracy: 0.6371
# Epoch 1/4, Batch Accuracy: 0.6371
# Epoch 1/4, Batch Accuracy: 0.6372
# Epoch 1/4, Batch Accuracy: 0.6374
# Epoch 1/4, Batch Accuracy: 0.6377
# Epoch 1/4, Batch Accuracy: 0.6377
# Epoch 1/4, Batch Accuracy: 0.6377
# Epoch 1/4, Batch Accuracy: 0.6378
# Epoch 1/4, Batch Accuracy: 0.6379
# Epoch 1/4, Batch Accuracy: 0.6381
# Epoch 1/4, Batch Accuracy: 0.6382
# Epoch 1/4, Batch Accuracy: 0.6383
# Epoch 1/4, Batch Accuracy: 0.6384
# Epoch 1/4, Batch Accuracy: 0.6384
# Epoch 1/4, Batch Accuracy: 0.6386
# Epoch 1/4, Batch Accuracy: 0.6387
# Epoch 1/4, Batch Accuracy: 0.6389
# Epoch 1/4, Batch Accuracy: 0.6390
# Epoch 1/4, Batch Accuracy: 0.6391
# Epoch 1/4, Batch Accuracy: 0.6392
# Epoch 1/4, Batch Accuracy: 0.6393
# Epoch 1/4, Batch Accuracy: 0.6394
# Epoch 1/4, Batch Accuracy: 0.6395
# Epoch 1/4, Batch Accuracy: 0.6397
# Epoch 1/4, Batch Accuracy: 0.6399
# Epoch 1/4, Batch Accuracy: 0.6400
# Epoch 1/4, Batch Accuracy: 0.6402
# Epoch 1/4, Batch Accuracy: 0.6400
# Epoch 1/4, Batch Accuracy: 0.6403
# Epoch 1/4, Batch Accuracy: 0.6405
# Epoch 1/4, Batch Accuracy: 0.6406
# Epoch 1/4, Batch Accuracy: 0.6406
# Epoch 1/4, Batch Accuracy: 0.6406
# Epoch 1/4, Batch Accuracy: 0.6408
# Epoch 1/4, Batch Accuracy: 0.6410
# Epoch 1/4, Batch Accuracy: 0.6409
# Epoch 1/4, Batch Accuracy: 0.6411
# Epoch 1/4, Batch Accuracy: 0.6412
# Epoch 1/4, Batch Accuracy: 0.6411
# Epoch 1/4, Batch Accuracy: 0.6411
# Epoch 1/4, Batch Accuracy: 0.6411
# Epoch 1/4, Batch Accuracy: 0.6413
# Epoch 1/4, Batch Accuracy: 0.6415
# Epoch 1/4, Batch Accuracy: 0.6416
# Epoch 1/4, Batch Accuracy: 0.6417
# Epoch 1/4, Batch Accuracy: 0.6419
# Epoch 1/4, Batch Accuracy: 0.6420
# Epoch 1/4, Batch Accuracy: 0.6421
# Epoch 1/4, Batch Accuracy: 0.6421
# Epoch 1/4, Batch Accuracy: 0.6422
# Epoch 1/4, Batch Accuracy: 0.6423
# Epoch 1/4, Batch Accuracy: 0.6425
# Epoch 1/4, Batch Accuracy: 0.6427
# Epoch 1/4, Batch Accuracy: 0.6429
# Epoch 1/4, Batch Accuracy: 0.6431
# Epoch 1/4, Batch Accuracy: 0.6431
# Epoch 1/4, Batch Accuracy: 0.6432
# Epoch 1/4, Batch Accuracy: 0.6433
# Epoch 1/4, Batch Accuracy: 0.6435
# Epoch 1/4, Batch Accuracy: 0.6436
# Epoch 1/4, Batch Accuracy: 0.6436
# Epoch 1/4, Batch Accuracy: 0.6437
# Epoch 1/4, Batch Accuracy: 0.6439
# Epoch 1/4, Batch Accuracy: 0.6440
# Epoch 1/4, Batch Accuracy: 0.6441
# Epoch 1/4, Batch Accuracy: 0.6440
# Epoch 1/4, Batch Accuracy: 0.6441
# Epoch 1/4, Batch Accuracy: 0.6441
# Epoch 1/4, Batch Accuracy: 0.6443
# Epoch 1/4, Batch Accuracy: 0.6443
# Epoch 1/4, Batch Accuracy: 0.6444
# Epoch 1/4, Batch Accuracy: 0.6445
# Epoch 1/4, Batch Accuracy: 0.6447
# Epoch 1/4, Batch Accuracy: 0.6447
# Epoch 1/4, Batch Accuracy: 0.6446
# Epoch 1/4, Batch Accuracy: 0.6448
# Epoch 1/4, Batch Accuracy: 0.6447
# Epoch 1/4, Batch Accuracy: 0.6450
# Epoch 1/4, Batch Accuracy: 0.6451
# Epoch 1/4, Batch Accuracy: 0.6451
# Epoch 1/4, Batch Accuracy: 0.6452
# Epoch 1/4, Batch Accuracy: 0.6453
# Epoch 1/4, Batch Accuracy: 0.6455
# Epoch 1/4, Batch Accuracy: 0.6458
# Epoch 1/4, Batch Accuracy: 0.6460
# Epoch 1/4, Batch Accuracy: 0.6461
# Epoch 1/4, Batch Accuracy: 0.6462
# Epoch 1/4, Batch Accuracy: 0.6464
# Epoch 1/4, Batch Accuracy: 0.6465
# Epoch 1/4, Batch Accuracy: 0.6466
# Epoch 1/4, Batch Accuracy: 0.6466
# Epoch 1/4, Batch Accuracy: 0.6466
# Epoch 1/4, Batch Accuracy: 0.6466
# Epoch 1/4, Batch Accuracy: 0.6468
# Epoch 1/4, Batch Accuracy: 0.6469
# Epoch 1/4, Batch Accuracy: 0.6471
# Epoch 1/4, Batch Accuracy: 0.6469
# Epoch 1/4, Batch Accuracy: 0.6471
# Epoch 1/4, Batch Accuracy: 0.6471
# Epoch 1/4, Batch Accuracy: 0.6472
# Epoch 1/4, Batch Accuracy: 0.6472
# Epoch 1/4, Batch Accuracy: 0.6474
# Epoch 1/4, Batch Accuracy: 0.6476
# Epoch 1/4, Batch Accuracy: 0.6477
# Epoch 1/4, Batch Accuracy: 0.6476
# Epoch 1/4, Batch Accuracy: 0.6478
# Epoch 1/4, Batch Accuracy: 0.6481
# Epoch 1/4, Batch Accuracy: 0.6481
# Epoch 1/4, Batch Accuracy: 0.6481
# Epoch 1/4, Batch Accuracy: 0.6483
# Epoch 1/4, Batch Accuracy: 0.6484
# Epoch 1/4, Batch Accuracy: 0.6484
# Epoch 1/4, Batch Accuracy: 0.6486
# Epoch 1/4, Batch Accuracy: 0.6485
# Epoch 1/4, Batch Accuracy: 0.6486
# Epoch 1/4, Batch Accuracy: 0.6487
# Epoch 1/4, Batch Accuracy: 0.6488
# Epoch 1/4, Batch Accuracy: 0.6489
# Epoch 1/4, Batch Accuracy: 0.6490
# Epoch 1/4, Batch Accuracy: 0.6490
# Epoch 1/4, Batch Accuracy: 0.6489
# Epoch 1/4, Batch Accuracy: 0.6488
# Epoch 1/4, Batch Accuracy: 0.6489
# Epoch 1/4, Batch Accuracy: 0.6491
# Epoch 1/4, Batch Accuracy: 0.6491
# Epoch 1/4, Batch Accuracy: 0.6493
# Epoch 1/4, Batch Accuracy: 0.6495
# Epoch 1/4, Batch Accuracy: 0.6497
# Epoch 1/4, Batch Accuracy: 0.6497
# Epoch 1/4, Batch Accuracy: 0.6497
# Epoch 1/4, Batch Accuracy: 0.6499
# Epoch 1/4, Batch Accuracy: 0.6499
# Epoch 1/4, Batch Accuracy: 0.6501
# Epoch 1/4, Batch Accuracy: 0.6502
# Epoch 1/4, Batch Accuracy: 0.6501
# Epoch 1/4, Batch Accuracy: 0.6501
# Epoch 1/4, Batch Accuracy: 0.6502
# Epoch 1/4, Batch Accuracy: 0.6502
# Epoch 1/4, Batch Accuracy: 0.6501
# Epoch 1/4, Batch Accuracy: 0.6504
# Epoch 1/4, Batch Accuracy: 0.6505
# Epoch 1/4, Batch Accuracy: 0.6505
# Epoch 1/4, Batch Accuracy: 0.6507
# Epoch 1/4, Batch Accuracy: 0.6506
# Epoch 1/4, Batch Accuracy: 0.6508
# Epoch 1/4, Batch Accuracy: 0.6509
# Epoch 1/4, Batch Accuracy: 0.6510
# Epoch 1/4, Batch Accuracy: 0.6509
# Epoch 1/4, Batch Accuracy: 0.6510
# Epoch 1/4, Batch Accuracy: 0.6510
# Epoch 1/4, Batch Accuracy: 0.6510
# Epoch 1/4, Batch Accuracy: 0.6511
# Epoch 1/4, Batch Accuracy: 0.6514
# Epoch 1/4, Batch Accuracy: 0.6514
# Epoch 1/4, Batch Accuracy: 0.6513
# Epoch 1/4, Batch Accuracy: 0.6515
# Epoch 1/4, Batch Accuracy: 0.6516
# Epoch 1/4, Batch Accuracy: 0.6517
# Epoch 1/4, Batch Accuracy: 0.6516
# Epoch 1/4, Batch Accuracy: 0.6518
# Epoch 1/4, Batch Accuracy: 0.6520
# Epoch 1/4, Batch Accuracy: 0.6519
# Epoch 1/4, Batch Accuracy: 0.6519
# Epoch 1/4, Batch Accuracy: 0.6519
# Epoch 1/4, Batch Accuracy: 0.6520
# Epoch 1/4, Batch Accuracy: 0.6521
# Epoch 1/4, Batch Accuracy: 0.6522
# Epoch 1/4, Batch Accuracy: 0.6523
# Epoch 1/4, Batch Accuracy: 0.6524
# Epoch 1/4, Batch Accuracy: 0.6524
# Epoch 1/4, Batch Accuracy: 0.6525
# Epoch 1/4, Batch Accuracy: 0.6526
# Epoch 1/4, Batch Accuracy: 0.6525
# Epoch 1/4, Batch Accuracy: 0.6528
# Epoch 1/4, Batch Accuracy: 0.6529
# Epoch 1/4, Batch Accuracy: 0.6530
# Epoch 1/4, Batch Accuracy: 0.6531
# Epoch 1/4, Batch Accuracy: 0.6531
# Epoch 1/4, Batch Accuracy: 0.6533
# Epoch 1/4, Batch Accuracy: 0.6533
# Epoch 1/4, Batch Accuracy: 0.6534
# Epoch 1/4, Batch Accuracy: 0.6536
# Epoch 1/4, Batch Accuracy: 0.6537
# Epoch 1/4, Batch Accuracy: 0.6539
# Epoch 1/4, Batch Accuracy: 0.6539
# Epoch 1/4, Batch Accuracy: 0.6541
# Epoch 1/4, Batch Accuracy: 0.6541
# Epoch 1/4, Batch Accuracy: 0.6542
# Epoch 1/4, Batch Accuracy: 0.6543
# Epoch 1/4, Batch Accuracy: 0.6544
# Epoch 1/4, Batch Accuracy: 0.6543
# Epoch 1/4, Batch Accuracy: 0.6545
# Epoch 1/4, Batch Accuracy: 0.6545
# Epoch 1/4, Batch Accuracy: 0.6547
# Epoch 1/4, Batch Accuracy: 0.6547
# Epoch 1/4, Batch Accuracy: 0.6548
# Epoch 1/4, Batch Accuracy: 0.6548
# Epoch 1/4, Batch Accuracy: 0.6550
# Epoch 1/4, Batch Accuracy: 0.6549
# Epoch 1/4, Batch Accuracy: 0.6552
# Epoch 1/4, Batch Accuracy: 0.6552
# Epoch 1/4, Batch Accuracy: 0.6553
# Epoch 1/4, Batch Accuracy: 0.6552
# Epoch 1/4, Batch Accuracy: 0.6551
# Epoch 1/4, Batch Accuracy: 0.6553
# Epoch 1/4, Batch Accuracy: 0.6555
# Epoch 1/4, Batch Accuracy: 0.6555
# Epoch 1/4, Batch Accuracy: 0.6555
# Epoch 1/4, Batch Accuracy: 0.6556
# Epoch 1/4, Batch Accuracy: 0.6557
# Epoch 1/4, Batch Accuracy: 0.6559
# Epoch 1/4, Batch Accuracy: 0.6559
# Epoch 1/4, Batch Accuracy: 0.6558
# Epoch 1/4, Batch Accuracy: 0.6559
# Epoch 1/4, Batch Accuracy: 0.6560
# Epoch 1/4, Batch Accuracy: 0.6560
# Epoch 1/4, Batch Accuracy: 0.6561
# Epoch 1/4, Batch Accuracy: 0.6561
# Epoch 1/4, Batch Accuracy: 0.6561
# Epoch 1/4, Batch Accuracy: 0.6561
# Epoch 1/4, Batch Accuracy: 0.6564
# Epoch 1/4, Batch Accuracy: 0.6564
# Epoch 1/4, Batch Accuracy: 0.6564
# Epoch 1/4, Batch Accuracy: 0.6565
# Epoch 1/4, Batch Accuracy: 0.6566
# Epoch 1/4, Batch Accuracy: 0.6567
# Epoch 1/4, Batch Accuracy: 0.6568
# Epoch 1/4, Batch Accuracy: 0.6570
# Epoch 1/4, Batch Accuracy: 0.6570
# Epoch 1/4, Batch Accuracy: 0.6570
# Epoch 1/4, Batch Accuracy: 0.6571
# Epoch 1/4, Batch Accuracy: 0.6571
# Epoch 1/4, Batch Accuracy: 0.6573
# Epoch 1/4, Batch Accuracy: 0.6573
# Epoch 1/4, Batch Accuracy: 0.6574
# Epoch 1/4, Batch Accuracy: 0.6575
# Epoch 1/4, Batch Accuracy: 0.6576
# Epoch 1/4, Batch Accuracy: 0.6575
# Epoch 1/4, Batch Accuracy: 0.6576
# Epoch 1/4, Batch Accuracy: 0.6577
# Epoch 1/4, Batch Accuracy: 0.6579
# Epoch 1/4, Batch Accuracy: 0.6578
# Epoch 1/4, Batch Accuracy: 0.6579
# Epoch 1/4, Batch Accuracy: 0.6580
# Epoch 1/4, Batch Accuracy: 0.6581
# Epoch 1/4, Batch Accuracy: 0.6581
# Epoch 1/4, Batch Accuracy: 0.6582
# Epoch 1/4, Batch Accuracy: 0.6583
# Epoch 1/4, Batch Accuracy: 0.6584
# Epoch 1/4, Batch Accuracy: 0.6583
# Epoch 1/4, Batch Accuracy: 0.6585
# Epoch 1/4, Batch Accuracy: 0.6585
# Epoch 1/4, Batch Accuracy: 0.6586
# Epoch 1/4, Batch Accuracy: 0.6587
# Epoch 1/4, Batch Accuracy: 0.6586
# Epoch 1/4, Batch Accuracy: 0.6586
# Epoch 1/4, Batch Accuracy: 0.6585
# Epoch 1/4, Batch Accuracy: 0.6586
# Epoch 1/4, Batch Accuracy: 0.6587
# Epoch 1/4, Batch Accuracy: 0.6589
# Epoch 1/4, Batch Accuracy: 0.6589
# Epoch 1/4, Batch Accuracy: 0.6590
# Epoch 1/4, Batch Accuracy: 0.6591
# Epoch 1/4, Batch Accuracy: 0.6592
# Epoch 1/4, Batch Accuracy: 0.6594
# Epoch 1/4, Batch Accuracy: 0.6594
# Epoch 1/4, Batch Accuracy: 0.6597
# Epoch 1/4, Batch Accuracy: 0.6598
# Epoch 1/4, Batch Accuracy: 0.6598
# Epoch 1/4, Batch Accuracy: 0.6598
# Epoch 1/4, Batch Accuracy: 0.6598
# Epoch 1/4, Batch Accuracy: 0.6599
# Epoch 1/4, Batch Accuracy: 0.6600
# Epoch 1/4, Batch Accuracy: 0.6601
# Epoch 1/4, Batch Accuracy: 0.6602
# Epoch 1/4, Batch Accuracy: 0.6603
# Epoch 1/4, Batch Accuracy: 0.6604
# Epoch 1/4, Batch Accuracy: 0.6603
# Epoch 1/4, Batch Accuracy: 0.6603
# Epoch 1/4, Batch Accuracy: 0.6605
# Epoch 1/4, Batch Accuracy: 0.6606
# Epoch 1/4, Batch Accuracy: 0.6606
# Epoch 1/4, Batch Accuracy: 0.6607
# Epoch 1/4, Batch Accuracy: 0.6607
# Epoch 1/4, Batch Accuracy: 0.6607
# Epoch 1/4, Batch Accuracy: 0.6609
# Epoch 1/4, Batch Accuracy: 0.6609
# Epoch 1/4, Batch Accuracy: 0.6609
# Epoch 1/4, Batch Accuracy: 0.6610
# Epoch 1/4, Batch Accuracy: 0.6611
# Epoch 1/4, Batch Accuracy: 0.6612
# Epoch 1/4, Batch Accuracy: 0.6612
# Epoch 1/4, Batch Accuracy: 0.6612
# Epoch 1/4, Batch Accuracy: 0.6611
# Epoch 1/4, Batch Accuracy: 0.6612
# Epoch 1/4, Batch Accuracy: 0.6614
# Epoch 1/4, Batch Accuracy: 0.6613
# Epoch 1/4, Batch Accuracy: 0.6614
# Epoch 1/4, Batch Accuracy: 0.6615
# Epoch 1/4, Batch Accuracy: 0.6617
# Epoch 1/4, Batch Accuracy: 0.6616
# Epoch 1/4, Batch Accuracy: 0.6617
# Epoch 1/4, Batch Accuracy: 0.6618
# Epoch 1/4, Batch Accuracy: 0.6619
# Epoch 1/4, Batch Accuracy: 0.6619
# Epoch 1/4, Batch Accuracy: 0.6621
# Epoch 1/4, Batch Accuracy: 0.6621
# Epoch 1/4, Batch Accuracy: 0.6621
# Epoch 1/4, Batch Accuracy: 0.6623
# Epoch 1/4, Batch Accuracy: 0.6624
# Epoch 1/4, Batch Accuracy: 0.6626
# Epoch 1/4, Batch Accuracy: 0.6628
# Epoch 1/4, Batch Accuracy: 0.6628
# Epoch 1/4, Batch Accuracy: 0.6628
# Epoch 1/4, Batch Accuracy: 0.6628
# Epoch 1/4, Batch Accuracy: 0.6629
# Epoch 1/4, Batch Accuracy: 0.6630
# Epoch 1/4, Batch Accuracy: 0.6629
# Epoch 1/4, Batch Accuracy: 0.6630
# Epoch 1/4, Batch Accuracy: 0.6631
# Epoch 1/4, Batch Accuracy: 0.6632
# Epoch 1/4, Batch Accuracy: 0.6632
# Epoch 1/4, Batch Accuracy: 0.6633
# Epoch 1/4, Batch Accuracy: 0.6633
# Epoch 1/4, Batch Accuracy: 0.6634
# Epoch 1/4, Batch Accuracy: 0.6634
# Epoch 1/4, Batch Accuracy: 0.6635
# Epoch 1/4, Batch Accuracy: 0.6636
# Epoch 1/4, Batch Accuracy: 0.6636
# Epoch 1/4, Batch Accuracy: 0.6637
# Epoch 1/4, Batch Accuracy: 0.6638
# Epoch 1/4, Batch Accuracy: 0.6640
# Epoch 1/4, Batch Accuracy: 0.6641
# Epoch 1/4, Batch Accuracy: 0.6642
# Epoch 1/4, Batch Accuracy: 0.6642
# Epoch 1/4, Batch Accuracy: 0.6643
# Epoch 1/4, Batch Accuracy: 0.6643
# Epoch 1/4, Batch Accuracy: 0.6644
# Epoch 1/4, Batch Accuracy: 0.6645
# Epoch 1/4, Batch Accuracy: 0.6647
# Epoch 1/4, Batch Accuracy: 0.6647
# Epoch 1/4, Batch Accuracy: 0.6648
# Epoch 1/4, Batch Accuracy: 0.6648
# Epoch 1/4, Batch Accuracy: 0.6649
# Epoch 1/4, Batch Accuracy: 0.6650
# Epoch 1/4, Batch Accuracy: 0.6651
# Epoch 1/4, Batch Accuracy: 0.6653
# Epoch 1/4, Batch Accuracy: 0.6654
# Epoch 1/4, Batch Accuracy: 0.6655
# Epoch 1/4, Batch Accuracy: 0.6655
# Epoch 1/4, Batch Accuracy: 0.6656
# Epoch 1/4, Batch Accuracy: 0.6656
# Epoch 1/4, Batch Accuracy: 0.6656
# Epoch 1/4, Batch Accuracy: 0.6656
# Epoch 1/4, Batch Accuracy: 0.6656
# Epoch 1/4, Batch Accuracy: 0.6656
# Epoch 1/4, Batch Accuracy: 0.6657
# Epoch 1/4, Batch Accuracy: 0.6658
# Epoch 1/4, Batch Accuracy: 0.6659
# Epoch 1/4, Batch Accuracy: 0.6660
# Epoch 1/4, Batch Accuracy: 0.6660
# Epoch 1/4, Batch Accuracy: 0.6661
# Epoch 1/4, Batch Accuracy: 0.6663
# Epoch 1/4, Batch Accuracy: 0.6665
# Epoch 1/4, Batch Accuracy: 0.6665
# Epoch 1/4, Batch Accuracy: 0.6665
# Epoch 1/4, Batch Accuracy: 0.6665
# ...
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8689
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8688
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8686
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
# Epoch 4/4, Batch Accuracy: 0.8687
#   0%|          | 0/1263 [00:00<?, ?it/s]
# Epoch 4/4, Train Loss: 0.3549, Train Accuracy: 0.8687, Test Loss: 0.4369, Test Accuracy: 0.8419
#   0%|          | 0/1263 [00:00<?, ?it/s]
# F1 Score: 0.8419686054521724

# %%
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
  #y_batch = y_batch.to(device)
  y_pred = model(input_ids_batch, attention_mask=attention_masks_batch)[0]
  _, predicted = torch.max(y_pred, 1)
  test_correct += (predicted == y_batch).sum()
  test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)
# Out:
#   0%|          | 0/1263 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2674: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Accuracy: tensor(0.8419)

# %%
# 모델 저장하기
torch.save(model.state_dict(), "modelfinal.pt")

# %%
# 토크나이저 설정
tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

# %%
koelectra_tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

result = koelectra_tokenizer.tokenize("너는 내년 대선 때 투표할 수 있어?")
print(result)
print([koelectra_tokenizer.encode(token) for token in result])
# Out:
# ['너', '##는', '내년', '대선', '때', '투표', '##할', '수', '있', '##어', '?']
# [[2, 2267, 3], [2, 7, 7, 2331, 3], [2, 6821, 3], [2, 7167, 3], [2, 2468, 3], [2, 7070, 3], [2, 7, 7, 3758, 3], [2, 2967, 3], [2, 3249, 3], [2, 7, 7, 3114, 3], [2, 35, 3]]

# %%
# 감정 예측 함수
def predict_emotion(input_sentence):
    inputs = tokenizer(input_sentence, return_tensors="pt", max_length=75, padding=True, truncation=True)
    input_ids = inputs["input_ids"]
    attention_mask = inputs["attention_mask"]

    with torch.no_grad():
        output = model(input_ids, attention_mask=attention_mask)
        logits = output.logits

    predicted_label = torch.argmax(logits, dim=1).item()
    emotions = ["anger", "happy", "panic", "sadness"]
    predicted_emotion = emotions[predicted_label]

    return predicted_emotion

# %%
class_names = ["anger", "happy", "panic", "sadness"]
def predict_with_prob(input_sentence):
    inputs = tokenizer(input_sentence, return_tensors="pt", max_length=75, padding=True, truncation=True)
    input_ids = inputs["input_ids"]
    attention_mask = inputs["attention_mask"]

    # 모델을 사용하여 감정 예측
    outputs = model(input_ids, attention_mask)
    logits = outputs.logits
    probs = torch.softmax(logits, dim=1)

    # 예측된 감정
    predicted_class_idx = torch.argmax(logits, dim=1).item()
    predicted_emotion = class_names[predicted_class_idx]

    # 각 클래스(감정)별 확률
    class_probs = probs.squeeze().tolist()

    # 결과 반환
    return predicted_emotion, class_probs

# %%
# 질문 무한반복하기! 0 입력시 종료
end = 1
while end == 1:
    sentence = input("하고싶은 말을 입력해주세요 : ")
    if sentence == "0":
        break
    print("입력한 문장:", sentence)

    # 감정 예측 및 각 클래스(감정)별 확률 출력
    predicted_emotion, class_probs = predict_with_prob(sentence)
    print("예측된 감정:", predicted_emotion)
    print("각 클래스별 확률:")
    for class_name, prob in zip(class_names, class_probs):
        print(f"{class_name}: {prob*100:.2f}%")
    print("\n")
# Out:
# 하고싶은 말을 입력해주세요 : 드디어 끝났다
# 입력한 문장: 드디어 끝났다
# 예측된 감정: happy
# 각 클래스별 확률:
# anger: 0.48%
# happy: 95.49%
# panic: 3.78%
# sadness: 0.26%
#
#
# 하고싶은 말을 입력해주세요 : 0

# %%
# 모델 저장 경로
model_save_path = '/content/model.pt'

# 모델 저장
torch.save(model.state_dict(), model_save_path)
